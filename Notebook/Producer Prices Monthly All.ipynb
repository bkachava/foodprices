# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("Datasets/Prices_Monthly_E_All_Data.csv", encoding = "latin1")

# %%
df.head()
# Out:
#    Area Code     Area  Item Code    Item  Element Code  \
# 0          3  Albania        515  Apples          5530
# 1          3  Albania        515  Apples          5530
# 2          3  Albania        515  Apples          5530
# 3          3  Albania        515  Apples          5530
# 4          3  Albania        515  Apples          5530
#
#                       Element  Months Code    Months Unit  Y2010   ...    \
# 0  Producer Price (LCU/tonne)         7001   January  LCU    NaN   ...
# 1  Producer Price (LCU/tonne)         7002  February  LCU    NaN   ...
# 2  Producer Price (LCU/tonne)         7003     March  LCU    NaN   ...
# 3  Producer Price (LCU/tonne)         7004     April  LCU    NaN   ...
# 4  Producer Price (LCU/tonne)         7005       May  LCU    NaN   ...
#
#      Y2013  Y2013F    Y2014  Y2014F    Y2015  Y2015F    Y2016  Y2016F  \
# 0  60000.0     NaN  45000.0     NaN  46000.0     NaN  45675.4     NaN
# ...

# %%
#See columns and datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48198 entries, 0 to 48197
# Data columns (total 25 columns):
# Area Code       48198 non-null int64
# Area            48198 non-null object
# Item Code       48198 non-null int64
# Item            48198 non-null object
# Element Code    48198 non-null int64
# Element         48198 non-null object
# Months Code     48198 non-null int64
# Months          48198 non-null object
# Unit            48198 non-null object
# Y2010           22063 non-null float64
# Y2010F          0 non-null float64
# Y2011           22518 non-null float64
# Y2011F          0 non-null float64
# Y2012           24324 non-null float64
# Y2012F          0 non-null float64
# Y2013           26016 non-null float64
# Y2013F          0 non-null float64
# Y2014           26735 non-null float64
# Y2014F          0 non-null float64
# Y2015           27002 non-null float64
# Y2015F          24 non-null object
# Y2016           28613 non-null float64
# ...

# %%
#See unique values per column
for column in df:
    print(column)
    print(df[column].unique())
# Out:
# Area Code
# [  3   4   9   1  11  52  16  14  57 255  53  18  19  21  26  27 233  35
#  115  32  33  39  40 351  41  44  46  48  98 167  54  56  58  59  60 238
#   66  67  75  79  81  86  91  97  99 101 105 106 110 112 108 114 118 113
#  120 119 121 126 256 129 130 131 132 133 134 137 141 144 150 157 158 299
#  166 169 170 171 173 174 177 117 183 185 184 188 191 244 194 272 196 197
#  199 198 202 203  38 276 207 210 212 216 217 220 223 230 229 231 234 236
#  237 251 181]
# Area
# ['Albania' 'Algeria' 'Argentina' 'Armenia' 'Austria' 'Azerbaijan'
#  'Bangladesh' 'Barbados' 'Belarus' 'Belgium' 'Benin' 'Bhutan'
#  'Bolivia (Plurinational State of)' 'Brazil' 'Brunei Darussalam'
#  'Bulgaria' 'Burkina Faso' 'Cabo Verde' 'Cambodia' 'Cameroon' 'Canada'
#  'Chad' 'Chile' 'China' 'China, mainland' 'Colombia' 'Congo' 'Costa Rica'
#  'Croatia' 'Czechia' 'Denmark' 'Dominican Republic' 'Ecuador' 'Egypt'
#  'El Salvador' 'Ethiopia' 'Fiji' 'Finland' 'Gambia' 'Germany' 'Ghana'
# ...

# %%
##Remove columns YxxxxF as they do not have values
df = df[df.columns.drop(list(df.filter(regex='F')))]

# %%
#Selecting prices in USD 
df = df[df["Element"] == "Producer Price (USD/tonne)"]

# %%
df
# Out:
# Empty DataFrame
# Columns: [Area Code, Area, Item Code, Item, Element Code, Element, Months Code, Months, Unit, Y2010, Y2011, Y2012, Y2013, Y2014, Y2015, Y2016, Y2017]
# Index: []

# %% [markdown]
# This dataset contains prices in Local Currency Units only. In order to compare prices between countries we require to convert prices into a single currency considering the exchange rate and deflation per month.
